# %% [markdown]
# # Identifying spam e-mails with machine learning
#
# A common use for binary classification is sorting spam e-mails from legitimate e-mails. Machine-learning models that classify e-mails as spam or not spam typically use the [Naive Bayes](https://en.wikipedia.org/wiki/Naive_Bayes_classifier) learning algorithm because it has proven to be effective at identifying spam, even with relatively small training sets. Let's build a Naive Bayes classification model and train it with 1,000 e-mails labeled with 0s (for not spam) and 1s (for spam) and then run a few e-mails through it to see how well it performs.

# %% [markdown]
# ## Load and prepare the data
#
# The first step is to load the dataset and prepare it for use in machine learning. Because machine-learning models can't deal with text, we'll use scikit-learn's [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) class to vectorize the text in the training e-mails. Then we'll split the data for training and testing.

# %%
import pandas as pd

df = pd.read_csv('Data/ham-spam.csv')
df.head()
# Out:
#    IsSpam                                               Text
# 0       0  key issues going forwarda year end reviews rep...
# 1       0  congrats contratulations the execution the cen...
# 2       0   key issues going forwardall under control set...
# 3       0  epmi files protest entergy transcoattached our...
# 4       0  california power please contact kristin walsh ...

# %% [markdown]
# Find out how many rows the dataset contains and confirm that there are no missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   IsSpam  1000 non-null   int64
#  1   Text    1000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %% [markdown]
# Check for duplicate rows in the dataset.

# %%
df.groupby('IsSpam').describe()
# Out:
#         Text
#        count unique                                                top freq
# IsSpam
# 0        500    499   paso firm capacity award memorandumlouise del...    2
# 1        500    500  premium online medicine heredichotomize prodig...    1

# %% [markdown]
# The dataset contains one duplicate row. Let's remove it and check for balance.

# %%
df = df.drop_duplicates()
df.groupby('IsSpam').describe()
# Out:
#         Text
#        count unique                                                top freq
# IsSpam
# 0        499    499   lko nothing will give you the print out along...    1
# 1        500    500  premium online medicine heredichotomize prodig...    1

# %% [markdown]
# Use [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) to vectorize the text in the DataFrame's "Text" column using a built-in dictionary of stop words.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(ngram_range=(1, 2), stop_words='english')
x = vectorizer.fit_transform(df['Text'])
y = df['IsSpam']

# %% [markdown]
# Show the vocabulary that `CountVectorizer` built from the training e-mails.

# %%
vectorizer.vocabulary_
# Out:
# {'key': 50036,
#  'issues': 48310,
#  'going': 40119,
#  'forwarda': 37692,
#  'year': 99702,
#  'end': 31413,
#  'reviews': 77698,
#  'report': 76304,
#  'needs': 60510,
#  'generating': 39353,
#  'like': 52433,
#  'mid': 57723,
#  'documenting': 27881,
#  'business': 12428,
#  'unit': 93760,
#  'performance': 66771,
#  'review': 77618,
#  'completion': 18806,
#  'david': 23666,
#  'john': 49105,
#  'work': 98732,
#  'plan': 67886,
#  'generation': 39362,
#  'nim': 61313,
#  'employees': 31202,
#  'hpl': 44127,
#  'transition': 92241,
#  'ongoing': 63430,
#  'officially': 63018,
#  'transferred': 92194,
#  'regardsdelainey': 75386,
#  'key issues': 50047,
#  'issues going': 48337,
#  'going forwarda': 40142,
#  'forwarda year': 37693,
#  'year end': 99733,
#  'end reviews': 31450,
#  'reviews report': 77707,
#  'report needs': 76342,
#  'needs generating': 60519,
#  'generating like': 39356,
#  'like mid': 52526,
#  'mid year': 57738,
#  'year documenting': 99731,
#  'documenting business': 27882,
#  'business unit': 12542,
#  'unit performance': 93775,
#  'performance review': 66798,
#  'review completion': 77630,
#  'completion david': 18810,
#  'david john': 23680,
#  'john work': 49173,
#  'work plan': 98799,
#  'plan generation': 67922,
#  'generation nim': 39379,
#  'nim issues': 61314,
#  'issues employees': 48325,
#  'employees david': 31209,
#  'john hpl': 49136,
#  'hpl transition': 44155,
#  'transition issues': 92247,
#  'issues ongoing': 48360,
#  'ongoing officially': 63435,
#  'officially transferred': 63024,
#  'transferred regardsdelainey': 92205,
#  'congrats': 19588,
#  'contratulations': 20618,
#  'execution': 33903,
#  'central': 14626,
#  'maine': 54769,
#  'sos': 84151,
#  'deal': 24072,
#  'great': 40792,
#  'example': 33709,
#  'comes': 17765,
#  'transaction': 91998,
#  'brings': 11748,
#  'strategic': 86014,
#  'value': 95204,
#  'nice': 61204,
#  'positions': 69030,
#  'book': 10997,
#  'quite': 73556,
#  'chunk': 15886,
#  'change': 14996,
#  'job': 49050,
#  'guys': 41545,
#  'hey': 43080,
#  'dana': 23284,
#  'paying': 66215,
#  'celebration': 14515,
#  'dinner': 26850,
#  'congrats contratulations': 19589,
#  'contratulations execution': 20619,
#  'execution central': 33904,
#  'central maine': 14632,
#  'maine sos': 54771,
#  'sos deal': 84152,
#  'deal great': 24129,
#  'great example': 40803,
#  'example comes': 33715,
#  'comes transaction': 17777,
#  'transaction brings': 92013,
#  'brings strategic': 11749,
#  'strategic value': 86020,
#  'value business': 95216,
#  'business nice': 12490,
#  'nice positions': 61210,
#  'positions book': 69032,
#  'book quite': 11012,
#  'quite nice': 73565,
#  'nice chunk': 61205,
#  'chunk change': 15887,
#  'change great': 15012,
#  'great job': 40811,
#  'job guys': 49058,
#  'guys hey': 41551,
#  'hey dana': 43082,
#  'dana paying': 23292,
#  'paying celebration': 66219,
#  'celebration dinner': 14516,
#  'forwardall': 37694,
#  'control': 20654,
#  'set': 81507,
#  'group': 41054,
#  'cindy': 15986,
#  'skinner': 83242,
#  'producing': 71123,
#  'stats': 85498,
#  'making': 55014,
#  'sure': 87368,
#  'don': 28219,
#  'cop': 20881,
#  'gone': 40242,
#  'wholesale': 97974,
#  'progress': 71519,
#  'fair': 34947,
#  'say': 79697,
#  'total': 91638,
#  'clarity': 16365,
#  'direction': 26961,
#  'memo': 57065,
#  'monday': 58650,
#  'olson': 63357,
#  'sent': 81088,
#  'email': 30896,
#  'community': 18261,
#  'embargo': 31026,
#  'staff': 84945,
#  'believe': 9248,
#  'mark': 55622,
#  'drafting': 28657,
#  'otc': 64527,
#  'fran': 37885,
#  'michele': 57669,
#  'cash': 14113,
#  'guy': 41538,
#  'yesterday': 99958,
#  'hand': 41762,
#  'daviddavid': 23706,
#  'delainey': 25003,
#  'pmto': 68379,
#  'lavorato': 51341,
#  'corp': 21048,
#  'enron': 31853,
#  'oxley': 64987,
#  'hou': 43982,
#  'ect': 29801,
#  'ectcc': 29968,
#  'frevert': 38142,
#  'greg': 40919,
#  'whalley': 97841,
#  'louise': 53978,
#  'kitchen': 50342,
#  'ectsubject': 29996,
#  'going forwardall': 40143,
#  'forwardall control': 37695,
#  'control set': 20689,
#  'set work': 81567,
#  'work group': 98769,
#  'group cindy': 41067,
#  'cindy skinner': 15995,
#  'skinner producing': 83246,
#  'producing stats': 71128,
#  'stats making': 85499,
#  'making sure': 55038,
#  'sure don': 87378,
#  'don cop': 28233,
#  'cop gone': 20882,
#  'gone wholesale': 40251,
#  'wholesale stats': 97996,
#  'stats progress': 85500,
#  'progress fair': 71525,
#  'fair say': 34955,
#  'say total': 79712,
#  'total clarity': 91645,
#  'clarity direction': 16366,
#  'direction memo': 26966,
#  'memo monday': 57073,
#  'monday cindy': 58657,
#  'cindy olson': 15992,
#  'olson sent': 63362,
#  'sent email': 81100,
#  'email community': 30920,
#  'community embargo': 18266,
#  'embargo hpl': 31027,
#  'hpl staff': 44148,
#  'staff believe': 84949,
#  'believe mark': 9275,
#  'mark drafting': 55632,
#  'drafting otc': 28659,
#  'otc fran': 64534,
#  'fran michele': 37892,
#  'michele cash': 57671,
#  'cash guy': 14132,
#  'guy yesterday': 41544,
#  'yesterday hand': 99976,
#  'hand daviddavid': 41763,
#  'daviddavid delainey': 23707,
#  'delainey pmto': 25019,
#  'pmto john': 68406,
#  'john lavorato': 49141,
#  'lavorato corp': 51343,
#  'corp enron': 21059,
#  'enron david': 31942,
#  'david oxley': 23688,
#  'oxley hou': 64993,
#  'hou ect': 43983,
#  'ect ectcc': 29844,
#  'ectcc mark': 29984,
#  'mark frevert': 55637,
#  'frevert enron': 38146,
#  'enron enron': 31968,
#  'enron greg': 32005,
#  'greg whalley': 40935,
#  'whalley hou': 97844,
#  'ect ect': 29843,
#  'ect louise': 29904,
#  'louise kitchen': 54003,
#  'kitchen hou': 50354,
#  'ect ectsubject': 29845,
#  'ectsubject key': 30012,
#  'epmi': 32738,
#  'files': 36099,
#  'protest': 72153,
#  'entergy': 32484,
#  'transcoattached': 92133,
#  'filing': 36114,
#  'protesting': 72157,
#  'proposed': 71989,
#  'transco': 92129,
#  'rate': 73901,
#  'premature': 69831,
#  'filed': 36079,
#  'join': 49211,
#  'sppno': 84755,
#  'support': 87261,
#  'innovative': 46743,
#  'rates': 73973,
#  'customer': 22915,
#  'funded': 38567,
#  'transmission': 92257,
#  'project': 71561,
#  'development': 26189,
#  'fee': 35585,
#  'extra': 34612,
#  'basis': 8712,
#  'points': 68567,
#  'certain': 14749,
#  'projects': 71696,
#  'exact': 33677,
#  'recovery': 74839,
#  'mechanismrequest': 56567,
#  'commission': 17995,
#  'require': 76649,
#  'grandfathered': 40680,
#  'contracts': 20512,
#  'addressedexpress': 1460,
#  'concern': 19107,
#  'request': 76577,
#  'continue': 20298,
#  'problematic': 70872,
#  'source': 84181,
#  'sink': 82941,
#  'limitations': 52677,
#  'forwarded': 37696,
#  'christi': 15804,
#  'nicolay': 61234,
#  'andrea': 4204,
#  'settanni': 81577,
#  'subject': 86391,
#  'rto': 78757,
#  'rtol': 78773,
#  'wpd': 99146,
#  'entergyr': 32491,
#  'epmi files': 32742,
#  'files protest': 36106,
#  'protest entergy': 72155,
#  'entergy transcoattached': 32490,
#  'transcoattached filing': 92134,
#  'filing yesterday': 36163,
#  'yesterday protesting': 99985,
#  'protesting entergy': 72158,
#  'entergy proposed': 32487,
#  'proposed transco': 72025,
#  'transco rate': 92132,
#  'rate issues': 73926,
#  'issues premature': 48366,
#  'premature entergy': 69832,
#  'entergy filed': 32486,
#  'filed join': 36085,
#  'join sppno': 49216,
#  'sppno support': 84756,
#  'support proposed': 87299,
#  'proposed innovative': 72008,
#  'innovative rates': 46746,
#  'rates example': 73989,
#  'example entergy': 33718,
#  'entergy customer': 32485,
#  'customer funded': 22934,
#  'funded transmission': 38571,
#  'transmission project': 92283,
#  'project development': 71585,
#  'development fee': 26227,
#  'fee extra': 35591,
#  'extra basis': 34613,
#  'basis points': 8749,
#  'points certain': 68570,
#  'certain projects': 14767,
#  'projects exact': 71709,
#  'exact recovery': 33682,
#  'recovery mechanismrequest': 74848,
#  'mechanismrequest commission': 56568,
#  'commission require': 18005,
#  'require grandfathered': 76663,
#  'grandfathered contracts': 40681,
#  'contracts addressedexpress': 20515,
#  'addressedexpress concern': 1461,
#  'concern entergy': 19114,
#  'entergy request': 32488,
#  'request continue': 76582,
#  'continue problematic': 20325,
#  'problematic source': 70873,
#  'source sink': 84209,
#  'sink limitations': 82942,
#  'limitations forwarded': 52680,
#  'forwarded christi': 37703,
#  'christi nicolay': 15805,
#  'nicolay hou': 61236,
#  'ect andrea': 29804,
#  'andrea settanni': 4206,
#  'settanni pmto': 81578,
#  'pmto subject': 68438,
#  'subject entergy': 86439,
#  'entergy rto': 32489,
#  'rto protest': 78766,
#  'protest rtol': 72156,
#  'rtol wpd': 78774,
#  'wpd entergyr': 99147,
#  'entergyr wpd': 32492,
#  'california': 13057,
#  'power': 69305,
#  'contact': 20060,
#  'kristin': 50761,
#  'walsh': 96687,
#  'robert': 78281,
#  'johnston': 49199,
#  'clarification': 16343,
#  'executive': 33914,
#  'summary': 86951,
#  'utility': 94937,
#  'bankruptcy': 8340,
#  'appears': 5021,
#  'increasingly': 45897,
#  'likely': 52602,
#  'week': 97367,
#  'unless': 93871,
#  'state': 85188,
#  'clear': 16478,
#  'hurdles': 44425,
#  'agreement': 2445,
#  'payback': 66203,
#  'bailout': 8017,
#  'increases': 45872,
#  'short': 82278,
#  'term': 88925,
#  'funding': 38576,
#  'dwr': 29287,
#  'purchases': 72764,
#  'disagreement': 27069,
#  'persists': 66985,
#  'gov': 40432,
#  'davis': 23736,
#  'democrats': 25316,
#  'legislature': 51848,
#  'paid': 65214,
#  'utilities': 94793,
#  'split': 84640,
#  'stock': 85792,
#  'warrant': 96948,
#  'versus': 95669,
#  'ownership': 64957,
#  'assets': 6406,
#  'economics': 29766,
#  'long': 53567,
#  'appear': 4993,
#  'hikes': 43287,
#  'unavoidable': 93373,
#  'need': 60294,
#  'amortize': 3772,
#  'undercollected': 93487,
#  'recent': 74608,
#  'freeze': 38104,
#  'period': 66842,
#  'air': 2676,
#  'quality': 73221,
#  'management': 55136,
#  'district': 27585,
#  'regulations': 75515,
#  'offer': 62737,
#  'limited': 52683,
#  'scope': 80072,
#  'providing': 72358,
#  'additional': 1343,
#  'capacity': 13594,
#  'feeling': 35642,
#  'intense': 47082,
#  'pressure': 70193,
#  'left': 51705,
#  'wing': 98266,
#  'consumer': 20002,
#  'groups': 41164,
#  'forced': 37283,
#  'slow': 83378,
#  'stop': 85887,
#  'hike': 43281,
#  'plans': 68040,
#  'senator': 80943,
#  'burton': 12366,
#  'eminent': 31115,
#  'domain': 28173,
#  'threats': 90359,
#  'generators': 39399,
#  'reflect': 75118,
#  'little': 53143,
#  'significance': 82621,
#  'outlook': 64694,
#  'rising': 78088,
#  'againa': 2207,
#  'finalize': 36273,
#  'debt': 24429,
#  'workout': 98945,
#  'continues': 20361,
#  'just': 49545,
#  'reach': 74122,
#  'creditors': 22161,
#  'time': 90609,
#  'running': 78918,
#  'forbearance': 37255,
#  'arrangement': 5965,
#  'expire': 34383,
#  'tuesday': 92805,
#  'socal': 83613,
#  'edison': 30055,
#  'bills': 10153,
#  'payroll': 66356,
#  'working': 98873,
#  'hard': 41967,
#  'indicated': 46050,
#  'feel': 35617,
#  'close': 16683,
#  'involuntary': 47820,
#  'occurs': 62602,
#  'days': 23950,
#  'court': 21672,
#  'accepts': 445,
#  'file': 36045,
#  'voluntary': 96377,
#  'opinion': 63749,
#  'assembly': 6347,
#  'divided': 27644,
#  'respect': 77040,
#  'assemblyman': 6357,
#  'keeley': 49888,
#  'told': 91296,
#  'resolved': 76971,
#  'day': 23860,
#  'hurry': 44434,
#  'believes': 9313,
#  'good': 40266,
#  'position': 68948,
#  'strong': 86172,
#  'arm': 5888,
#  'currently': 22771,
#  'does': 27940,
#  'intend': 47057,
#  'cede': 14488,
#  'avoid': 7632,
#  'stated': 85342,
#  'bad': 7961,
#  'worst': 99083,
#  'thing': 89968,
#  'possible': 69098,
#  'intends': 47079,
#  'stick': 85746,
#  'dismissed': 27414,
#  'governor': 40497,
#  'deadline': 24055,
#  'striking': 86155,
#  'avoided': 7659,
#  'minute': 58165,
#  'struck': 86212,
#  'receives': 74592,
#  'return': 77484,
#  'bailoutthe': 8029,
#  'federal': 35550,
#  'expected': 34163,
#  'rule': 78830,
#  'cpuc': 21885,
#  'undercollection': 93493,
#  'case': 14042,
#  'financing': 36426,
#  'available': 7464,
#  'buy': 12658,
#  'revenue': 77568,
#  'bonds': 10917,
#  'issued': 48266,
#  'possibility': 69084,
#  'significant': 82623,
#  'lead': 51481,
#  'extension': 34567,
#  'creditor': 22152,
#  'negative': 60559,
#  'tone': 91468,
#  'taken': 87929,
#  'standard': 85055,
#  'poors': 68760,
#  'concerning': 19147,
#  'delays': 25057,
#  'suggest': 86764,
#  'difficult': 26713,
#  'achieve': 860,
#  'previous': 70297,
#  'achieved': 873,
#  'high': 43163,
#  'level': 52156,
#  'washington': 96989,
#  'summit': 87055,
#  'happen': 41884,
#  'weekend': 97482,
#  'automatically': 7416,
#  'approved': 5360,
#  'non': 61454,
#  'energy': 31555,
#  'expenditures': 34241,
#  'government': 40449,
#  'risk': 78091,
#  'structure': 86215,
#  'place': 67808,
#  'recover': 74825,
#  'costs': 21352,
#  'expended': 34233,
#  'general': 39291,
#  'fund': 38466,
#  'debtwhile': 24473,
#  'succeeded': 86641,
#  'forcing': 37297,
#  'parents': 65507,
#  'eat': 29666,
#  'billion': 10092,
#  'final': 36212,
#  'held': 42537,
#  'fronts': 38309,
#  'unclear': 93438,
#  'mix': 58356,
#  'warrants': 96955,
#  'takeover': 87953,
#  'hydro': 44514,
#  'settled': 81597,
#  'second': 80335,
#  'hook': 43754,
#  'mixture': 58369,
#  'used': 94538,
#  'cost': 21272,
#  'finally': 36289,
#  'expect': 34112,
#  'politicians': 68651,
#  'minimize': 58097,
#  'force': 37272,
#  'appearance': 5012,
#  'tangible': 88135,
#  'politically': 68643,
#  'attractive': 7163,
#  'nebulous': 60225,
#  'price': 70340,
#  'purchase': 72705,
#  'valued': 95268,
#  'approximately': 5420,
#  'proceeds': 70938,
#  'pay': 66135,
#  'debts': 24465,
#  'money': 58715,
#  'existing': 34029,
#  'bondholders': 10906,
#  'ipp': 47934,
#  'sources': 84217,
#  'advise': 1859,
#  'bid': 9945,
#  'table': 87827,
#  'higher': 43206,
#  'contractsas': 20571,
#  'noted': 61734,
#  'announcement': 4519,
#  'contracted': 20480,
#  'come': 17677,
#  'line': 52756,
#  'immediately': 45106,
#  'remainder': 75915,
#  'reportedly': 76397,
#  'suppliers': 87180,
#  'building': 12145,
#  'plants': 68107,
#  'years': 99803,
#  'expressed': 34509,
#  'frustration': 38346,
#  'received': 74551,
#  'tablet': 87850,
#  'increase': 45800,
#  'means': 56500,
#  'acquire': 934,
#  'internal': 47256,
#  'market': 55656,
#  'cents': 14666,
#  'kwh': 50830,
#  'allows': 3245,
#  'number': 62117,
#  'slightly': 83336,
#  'different': 26683,
#  'assumption': 6700,
#  'based': 8615,
#  'natural': 60073,
#  'gas': 39016,
#  'efficiency': 30381,
#  'heating': 42457,
#  'numbers': 62213,
#  'quoted': 73591,
#  'industry': 46191,
#  'felt': 35697,
#  'unrealistic': 93948,
#  'agreed': 2415,
#  'optimistic': 63900,
#  'enormous': 31833,
#  'new': 60901,
#  'according': 561,
#  'assuming': 6692,
#  'settlement': 81603,
#  'reached': 74146,
#  'figure': 36018,
#  'charge': 15168,
#  'order': 64058,
#  'necessary': 60238,
#  'exemptionsthere': 33962,
#  'introduced': 47512,
#  'provide': 72209,
#  'exemptions': 33959,
#  'aqmd': 5568,
#  'republicans': 76547,
#  'asking': 6263,
#  'lift': 52393,
#  'environmental': 32633,
#  'site': 83007,
#  'facility': 34795,
#  'san': 79427,
#  'jose': 49296,
#  'denied': 25375,
#  'local': 53399,
#  'contemplation': 20229,
#  'loosening': 53746,
#  'compliance': 18837,
#  'restrictions': 77266,
#  'allow': 3204,
#  'dirtier': 27053,
#  'tocome': 91074,
#  'implementation': 45241,
#  'southern': 84280,
#  'moving': 59357,
#  'away': 7748,
#  'theuse': 89932,
#  'credits': 22197,
#  'apparently': 4968,
#  'drives': 28892,
#  'fired': 36523,
#  'democratic': 25308,
#  'moderates': 58534,
#  'pressured': 70207,
#  'advocatesthe': 1910,
#  'moderate': 58531,
#  'sen': 80922,
#  'puc': 72562,
#  'activists': 1117,
#  'afraid': 2108,
#  'harvey': 42069,
#  'rosenfield': 78579,
#  'consumers': 20019,
#  'movement': 59323,
#  'initiative': 46674,
#  'important': 45290,
#  'perspective': 67086,
#  'puts': 72892,
#  'far': 35164,
#  'challenge': 14918,
#  'defeat': 24816,
#  'election': 30630,
#  'distance': 27513,
#  'effectthe': 30377,
#  'seize': 80718,
#  'insure': 47006,
#  'continued': 20346,
#  'supply': 87213,
#  'apply': 5143,
#  'afederal': 2003,
#  'needed': 60462,
#  'canadian': 13429,
#  'essentially': 33140,
#  'untouchable': 94049,
#  'smaller': 83436,
#  'ipps': 47946,
#  'squeezemany': 84866,
#  'account': 588,
#  'production': 71170,
#  'amended': 3588,
#  'possibly': 69161,
#  'producers': 71111,
#  'credit': 22080,
#  'california power': 13133,
#  'power contact': 69340,
#  'contact kristin': 20103,
#  'kristin walsh': 50762,
#  'walsh robert': 96690,
#  'robert johnston': 78292,
#  'johnston clarification': 49201,
#  'clarification executive': 16345,
#  'executive summary': 33932,
#  'summary utility': 86991,
#  'utility bankruptcy': 94941,
#  'bankruptcy appears': 8343,
#  'appears increasingly': 5034,
#  'increasingly likely': 45903,
#  'likely week': 52640,
#  'week unless': 97473,
#  'unless state': 93887,
#  'state clear': 85214,
#  'clear hurdles': 16487,
#  'hurdles agreement': 44426,
#  'agreement payback': 2494,
#  'payback bailout': 66204,
#  'bailout rate': 8024,
#  'rate increases': 73923,
#  'increases short': 45883,
#  'short term': 82315,
#  'term funding': 88960,
#  'funding dwr': 38581,
#  'dwr purchases': 29318,
#  'purchases power': 72778,
#  'power disagreement': 69357,
#  'disagreement persists': 27070,
#  'persists gov': 66986,
#  'gov davis': 40433,
#  'davis democrats': 23767,
#  'democrats legislature': 25319,
#  'legislature state': 51877,
#  'state paid': 85279,
#  'paid bailout': 65225,
#  'bailout utilities': 8026,
#  'utilities split': 94907,
#  'split stock': 84651,
#  'stock warrant': 85834,
#  'warrant plan': 96950,
#  'plan versus': 67978,
#  'versus state': 95674,
#  'state ownership': 85278,
#  'ownership utility': 64972,
#  'utility transmission': 94976,
#  'transmission assets': 92261,
#  'assets economics': 6432,
#  'economics long': 29770,
#  'long term': 53601,
#  'term contracts': 88939,
#  'contracts appear': 20516,
#  'appear rate': 5008,
#  'rate hikes': 73919,
#  'hikes unavoidable': 43314,
#  'unavoidable need': 93374,
#  'need amortize': 60304,
#  'amortize undercollected': 3774,
#  'undercollected rates': 93491,
#  'rates utilities': 74014,
#  'utilities recent': 94888,
#  'recent rate': 74628,
#  'rate freeze': 73916,
#  'freeze period': 38106,
#  'period air': 66844,
#  'air quality': 2684,
#  'quality management': 73231,
#  'management district': 55149,
#  'district regulations': 27590,
#  'regulations review': 75527,
#  'review offer': 77661,
#  'offer limited': 62778,
#  'limited scope': 52706,
#  'scope providing': 80077,
#  'providing additional': 72359,
#  'additional generation': 1364,
#  'generation capacity': 39367,
#  'capacity legislature': 13605,
#  'legislature democrats': 51855,
#  'democrats feeling': 25317,
#  'feeling intense': 35644,
#  'intense pressure': 47084,
#  'pressure left': 70202,
#  'left wing': 51739,
#  'wing consumer': 98267,
#  'consumer groups': 20012,
#  'groups forced': 41179,
#  'forced slow': 37287,
#  'slow stop': 83387,
#  'stop davis': 85889,
#  'davis bailout': 23747,
#  'rate hike': 73918,
#  'hike plans': 43285,
#  'plans senator': 68064,
#  'senator burton': 80945,
#  'burton eminent': 12374,
#  'eminent domain': 31116,
#  'domain threats': 28176,
#  'threats generators': 90361,
#  'generators reflect': 39439,
#  'reflect pressure': 75125,
#  'pressure little': 70203,
#  'little significance': 53167,
#  'significance bankruptcy': 82622,
#  'bankruptcy outlook': 8390,
#  'outlook rising': 64698,
#  'rising againa': 78089,
#  'againa deal': 2208,
#  'deal finalize': 24125,
#  'finalize debt': 36274,
#  'debt workout': 24458,
#  'workout continues': 98946,
#  'continues just': 20372,
#  'just reach': 49622,
#  'reach state': 74142,
#  'state utilities': 85335,
#  'utilities creditors': 94824,
#  'creditors time': 22191,
#  'time running': 90748,
#  'running debt': 78926,
#  'debt forbearance': 24440,
#  'forbearance arrangement': 37258,
#  'arrangement set': 5977,
#  'set expire': 81521,
#  'expire tuesday': 34387,
#  'tuesday socal': 92821,
#  'socal edison': 83621,
#  'edison paying': 30071,
#  'paying bills': 66218,
#  'bills payroll': 10171,
#  'payroll working': 66362,
#  'working hard': 98901,
#  'hard cash': 41972,
#  'cash hand': 14133,
#  'hand indicated': 41764,
#  'indicated feel': 46057,
#  'feel close': 35622,
#  'close involuntary': 16705,
#  'involuntary bankruptcy': 47822,
#  'bankruptcy filing': 8369,
#  'filing filing': 36131,
#  'filing occurs': 36145,
#  'occurs days': 62603,
#  'days bankruptcy': 23957,
#  'bankruptcy court': 8359,
#  'court accepts': 21673,
#  'accepts filing': 446,
#  'filing utilities': 36160,
#  'utilities file': 94842,
#  'file voluntary': 36077,
#  'voluntary bankruptcy': 96378,
#  'bankruptcy opinion': 8388,
#  'opinion assembly': 63752,
#  'assembly divided': 6349,
#  'divided respect': 27646,
#  'respect outlook': 77054,
#  'outlook bankruptcy': 64695,
#  'bankruptcy assemblyman': 8344,
#  'assemblyman keeley': 6358,
#  'keeley told': 49898,
#  'told source': 91314,
#  'source filing': 84194,
#  'filing likely': 36139,
#  'likely resolved': 52629,
#  'resolved day': 76974,
#  'day period': 23911,
#  'period senator': 66864,
#  'senator john': 80947,
#  'john burton': 49116,
#  'burton hurry': 12376,
#  'hurry reach': 44437,
#  'reach deal': 74128,
#  'deal utilities': 24221,
#  'utilities believes': 94806,
#  'believes state': 9319,
#  'state california': 85211,
#  'california good': 13098,
#  'good position': 40306,
#  'position strong': 69003,
#  'strong arm': 86175,
#  'arm utilities': 5893,
#  'utilities burton': 94810,
#  'burton currently': 12371,
#  'currently does': 22781,
#  'does intend': 27963,
#  'intend cede': 47058,
#  'cede utilities': 14489,
#  'utilities avoid': 94803,
#  'avoid bankruptcy': 7634,
#  'bankruptcy senator': 8402,
#  'senator stated': 80950,
#  'stated bankruptcy': 85343,
#  'bankruptcy bad': 8347,
#  'bad worst': 7971,
#  'worst thing': 99085,
#  'thing possible': 89983,
#  'possible intends': 69117,
#  'intends stick': 47081,
#  'stick position': 85751,
#  'position senator': 69001,
#  'burton dismissed': 12373,
#  'dismissed governor': 27415,
#  'governor davis': 40509,
#  'davis end': 23771,
#  'end week': 31464,
#  'week deadline': 97384,
#  'deadline striking': 24061,
#  'striking deal': 86156,
#  'utilities bankruptcy': 94804,
#  'bankruptcy avoided': 8346,
#  'avoided minute': 7661,
#  'minute deal': 58169,
#  'deal struck': 24205,
#  'struck monday': 86214,
#  'monday state': 58692,
#  'state receives': 85294,
#  'receives return': 74596,
#  'return bailoutthe': 77485,
#  'bailoutthe scope': 8030,
#  'scope rate': 80078,
#  'hikes federal': 43296,
#  'federal court': 35555,
#  'court expected': 21693,
#  'expected rule': 34195,
#  'rule socal': 78836,
#  'socal cpuc': 83618,
#  'cpuc rate': 21903,
#  'rate undercollection': 73953,
#  'undercollection case': 93498,
#  'case monday': 14063,
#  'monday additional': 58652,
#  'additional financing': 1361,
#  'financing available': 36428,
#  'available dwr': 7484,
#  'dwr buy': 29289,
#  'buy power': 12686,
#  'power revenue': 69447,
#  'revenue bonds': 77569,
#  'bonds issued': 10928,
#  'issued possibility': 48284,
#  'possibility significant': 69097,
#  'significant progress': 82640,
#  'progress issues': 71530,
#  'issues lead': 48348,
#  'lead extension': 51491,
#  'extension creditor': 34569,
#  'creditor forbearance': 22154,
#  'forbearance negative': 37261,
#  'negative tone': 60570,
#  'tone taken': 91470,
#  'taken standard': 87947,
#  'standard poors': 85061,
#  'poors concerning': 68761,
#  'concerning delays': 19150,
#  'delays legislature': 25061,
#  'legislature suggest': 51878,
#  'suggest forbearance': 86771,
#  'forbearance difficult': 37259,
#  'difficult achieve': 26715,
#  'achieve previous': 867,
#  'previous forbearance': 70308,
#  'forbearance period': 37262,
#  'period achieved': 66843,
#  ...}

# %% [markdown]
# In addition to creating sparse matrices of vectorized text, `Countvectorizer` converts text to lowercase, removes stop words and punctuation characters, and more. Let's see how it cleans text before vectorizing it by transforming a string, and then reversing the transform.

# %%
text = vectorizer.transform(['Why pay MORE for * expensive meds when you can ...123... order them online and save $$$?'])
text = vectorizer.inverse_transform(text)
print(text)
# Out:
# [array(['expensive', 'meds', 'online', 'order', 'order online', 'pay',
#        'save'], dtype='<U401')]

# %% [markdown]
# Split the dataset so that 80% can be used for training and 20% for testing.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Train a Naive Bayes classifier
#
# The next step is to train a Naive Bayes classifier. We'll use scikit-learn's [MultinomialDB](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html) classifier, which is ideal for datasets vectorized by `CountVectorizer`.

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# Validate the trained model with the 20% of the dataset aside for testing and show a confusion matrix.

# %%
# %matplotlib inline
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(model, x_test, y_test, display_labels=['Not Spam', 'Spam'], cmap='Blues', xticks_rotation='vertical')

# %% [markdown]
# The model correctly identified 101 of 102 legitimate e-mails as not spam, and 95 of 98 spam e-mails as spam. Use the `score` method to get a rough measure of the model's accuracy.

# %%
model.score(x_test, y_test)
# Out:
# 0.98

# %% [markdown]
# Now retrieve the Receiver Operating Characteristic (ROC) metric for a better measure of accuracy.

# %%
from sklearn.metrics import roc_auc_score

probabilities = model.predict_proba(x_test)
roc_auc_score(y_test, probabilities[:, 1])
# Out:
# 0.9992997198879552

# %% [markdown]
# ## Use the model to classify e-mails
#
# Now let's see how the model classifies some sample e-mails. We'll start with a message that is not spam. The model's `predict` method predicts a class: 0 for not spam, or 1 for spam.

# %%
message = vectorizer.transform(['Can you attend a code review on Tuesday? Need to make sure the logic is rock solid.'])
model.predict(message)[0]
# Out:
# 0

# %% [markdown]
# What is the probability that the message is not spam? We can get that by calling `predict_proba`, which returns an array containing two values: the probability that the predicted class is 0, and the probability that the predicted class is 1, in that order.

# %%
model.predict_proba(message)[0][0]
# Out:
# 0.9999170457201042

# %% [markdown]
# Now test the model with a spam message.

# %%
message = vectorizer.transform(['Why pay more for expensive meds when you can order them online and save $$$?'])
model.predict(message)[0]
# Out:
# 1

# %% [markdown]
# What is the probability that the message is not spam?

# %%
model.predict_proba(message)[0][0]
# Out:
# 0.00021423891260677753

# %% [markdown]
# What is the probability that the message IS spam?

# %%
model.predict_proba(message)[0][1]
# Out:
# 0.9997857610873945

# %% [markdown]
# Observe that `predict` and `predict_proba` accept an array of inputs. Based on that, could you classify an entire batch of e-mails with one call to `predict` or `predict_proba`? How would you get the results for each e-mail?
